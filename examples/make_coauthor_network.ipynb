# %%
# %matplotlib widget
import sys
sys.path.insert(0,'../src/')

import pyconet as pcn
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({
    "font.family": "sans-serif",
    #"font.sans-serif": "Helvetica",
    "font.sans-serif": "Times New Roman",
})

# %%
author_obj = pcn.pyconet(query = "57225916320", is_query_name=False)

# %%
authors_to_exclude =   []
authors_to_emphasize = []
authors_special = []

# %%
fig = plt.figure(figsize=(10,7.5))
axs = fig.add_subplot(1,1,1)

pcn.plot_network(author_obj, fig=fig, axs=axs, authors_to_emphasize= authors_to_emphasize, 
                                               authors_special= authors_special, 
                                               authors_to_exclude= authors_to_exclude)
# Out:
# /Users/jayeshdhadphale/python_venvs/venv_local/lib/python3.10/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
